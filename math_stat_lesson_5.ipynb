# %%
import numpy as np

# %% [markdown]
# Задание 1. Известно, что генеральная совокупность распределена нормально
# со средним квадратическим отклонением, равным 16.
# Найти доверительный интервал для оценки математического ожидания a с надежностью 0.95,
# если выборочная средняя M = 80, а объем выборки n = 256.

# %% [markdown]
# Для таких задач можно использовать $t$-распределение. При заданной вероятности ($\lambda$) нужно рассчитать предельное
#
# отклонение от средней арифметической по следующей формуле:
# $$T_{1,2} = \overline{X} \pm \frac{s_0}{\sqrt{n}} \cdot c_{\gamma}$$
#
# где $T_1$, $T_2$ — нижняя и верхняя границы доверительного интервала,
#
# $\overline{X}$  — выборочное среднее арифметическое, $s_0$ — среднее квадратичное отклонение по выборке (несмещенное),
#
# $n$ — размер выборки,
#
# $\gamma$ — доверительная вероятность.
#
# <br>$\sigma$ - среднеквадратичное отклонение
# $$\sigma = \sqrt{\frac{\sum\limits_{i=1}^{n} (x_i - \overline{x})^2}{n}}$$
#
# $$p = 1 - α$$
# $$α=1-p$$
#
# Так как распределение нормальное, можем перейти от $α$ к $\frac{α}{2}$
# <br>$\sigma=16$
#
# $M(X)=a$
#
# $\overline{x}=80$
# <br>$n= 256$
# <br>$p=0.95$
#
# Известна $\sigma$ значит критерий оценки $c_{\gamma}$ является критерием Фишера $Z$ из таблицы распределения Лапласа
#
# $$α=1-0.95=0.05$$
# $$\frac{α}{2}=0.025$$
#
# Из таблицы накопленного нормально распределение находим $Z$ при $\frac{α}{2}=0.025$
# Получаем $Z=-1.96$

# %% [markdown]
# $$T_{1,2} = 80 \pm \frac{16}{\sqrt{256}} \cdot (-\frac{196}{100})=80 \pm \frac{16}{16} \cdot (-\frac{196}{100})=80 \pm (-1.96)$$
# $$T_{1}=80-1.96=78.04$$
# $$T_{2}=80+1.96=81.96$$

# %%
np.sqrt(256)
# Out:
# 16.0

# %% [markdown]
# Доверительный интервал нижняя и верхняя граница:
#
# $$T_{1}=78.04$$
# $$T_{2}=81.96$$

# %% [markdown]
# Задание 2. В результате 10 независимых измерений некоторой величины X, выполненных с одинаковой точностью, получены опытные данные: 6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1 Предполагая, что результаты измерений подчинены нормальному закону распределения вероятностей, оценить истинное значение величины X при помощи доверительного интервала, покрывающего это значение с доверительной вероятностью 0,95.

# %% [markdown]
# $$\overline{x}=\frac{6.9+6.1+6.2+6.8+7.5+6.3+6.4+6.9+6.7+6.1}{10}=\frac{65.9}{10}=6.59$$

# %%
6.9+6.1+6.2+6.8+7.5+6.3+6.4+6.9+6.7+6.1
# Out:
# 65.89999999999999

# %% [markdown]
# $n<100$ используем несмещенную оценку дисперсии
#
# $$\sigma_{несмещен} = \sqrt{\frac{\sum\limits_{i=1}^{n} (x_i - \overline{x})^2}{n-1}}$$

# %% [markdown]
# $$\sigma_{несмещен} = \sqrt{\frac{(6.9-6.59)^2+(6.1-6.59)^2+(6.2-6.59)^2+(6.8-6.59)^2+(7.5-6.59)^2+(6.3-6.59)^2+(6.4-6.59)^2+(6.9-6.59)^2+(6.7-6.59)^2+(6.1-6.59)^2}{10-1}}=\sqrt{\frac{(0.31)^2+(-0.49)^2+(-0.39)^2+(0.21)^2+(0.91)^2+(-0.29)^2+(-0.19)^2+(0.31)^2+(0.11)^2+(-0.49)^2}{9}}=\sqrt{\frac{0.0961+0.2401+0.1521+0.0441+0.8281+0.0841+0.0361+0.0961+0.0121+0.2401}{9}}=\sqrt{\frac{1.829}{9}}=\frac{\sqrt{1.829}}{3}=0.4508$$
# $$\sigma^2_{несмещен} = \frac{1.829}{9}=0.20322$$

# %% [markdown]
# Так как не был произведен анализ и $\sigma$ неизвестна, то критерий оценки = критерию Стьюдента $T$ из таблицы $K = n-1$, значит $К=10-1=9$
#
# Критерий оценки $K_{\frac{α}{2}}=T_{\frac{α}{2}} = 2.262$ при $p=1-\frac{α}{2}=0.975$
#
# <br>$p=0.95$
#
# $$α=1-0.95=0.05$$
# $$\frac{α}{2}=0.025$$

# %%
0.0961+0.2401+0.1521+0.0441+0.8281+0.0841+0.0361+0.0961+0.0121+0.2401
# Out:
# 1.8290000000000002

# %%
np.sqrt(1.829)
# Out:
# 1.352405264704334

# %%
a=[6.9, 6.1, 6.2, 6.8, 7.5, 6.3, 6.4, 6.9, 6.7, 6.1]
np.var(a, ddof=1)
# Out:
# 0.2032222222222223

# %%
np.sqrt(1829/9000)
# Out:
# 0.4508017549014447

# %% [markdown]
# $$T_{1,2} = 6.59 \pm \frac{0.4506}{\sqrt{10}} \cdot 2.262$$

# %% [markdown]
# $$T_{1,2} = 6.59 \pm \sqrt{\frac{1.829}{9*10}} \cdot 2.262=6.59 \pm \sqrt{\frac{1829}{1000*9*10}} \cdot 2.262=6.59 \pm \frac{\sqrt{1829}}{300} \cdot 2.262=6.59 \pm \sqrt{1829} \cdot 0.00754=6.59 \pm 42.7668 \cdot 0.00754=6.59 \pm 0.3224$$
#
# $$T_{1}=6.9124$$
# $$T_{2}=6.2676$$
#
# $[6.2676; 6.9124]$ этот интервал покрывает истинное значение $X$ с доверительной вероятностью $0.95$

# %%
np.sqrt(1829)
# Out:
# 42.76680956068619

# %% [markdown]
# Задание 3. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 мм.

# %% [markdown]
# <br>$\sigma=4$
#
# $M(X)=a$
#
# $\overline{x}=17.5$
# <br>$n= 100$
# <br>$α=0.05$
# <br>$p=0.95$
#
# 1) $H_0: S=S_0$
# 2) $H_1: S>S_0$
#
# Если критерий расчетный < критерия табличного, то принимаем гипотезу $H_0$
# <br>Если критерий расчетный > критерия табличного, то принимаем гипотезу $H_1$
#
# $$T_{1,2} = \overline{X} \pm \frac{s_0}{\sqrt{n}} \cdot c_{\gamma}$$
#
# Известна $\sigma$ значит критерий оценки $c_{\gamma}$ является критерием Фишера $Z$ из таблицы распределения Лапласа
#
# $$α=0.05$$
# $$1-α=p=0.95$$
#
# $Z_{расчетное} = \frac {17.5-17}{\frac{\sigma}{\sqrt{n}}}=\frac {0.5}{\frac{4}{\sqrt{100}}}=\frac {0.5}{\frac{4}{10}}=\frac{5}{4}=1.25$
#
# Из таблицы накопленного нормально распределение при $X>0$ находим $Z$ при $1-α=0.95$
# Получаем $Z=1.65$

# %% [markdown]
# $Z_{расчетное} < Z_{табличное}$
#
# Ответ: значит принимаем гипотезу $H_0$ с средним значением детали 17мм

# %% [markdown]
# Задача 4. Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?

# %% [markdown]
# $α=1-p=1%$
#
# $n=10$
#
# $W_{0}=200$
#
# $W_{1}=198.5$

# %% [markdown]
# $$\overline{x}=\frac{202+203+199+197+195+201+200+204+194+190}{10}=\frac{1985}{10}=198.5$$

# %% [markdown]
# Гипотеза $H_0: W=W_0$
# <br>Гипотеза $H_1: W не равно W_0$
#
# Если критерий расчетный < критерия табличного, то принимаем гипотезу $H_0$
# <br>Если критерий расчетный > критерия табличного, то принимаем гипотезу $H_1$
#
# $\sigma$ не известна, не было анализа
#
# Значит критерий $К$ равен критерию $Т$(Стьюдента) из таблицы Стьюдента.
#
# В формуле учитываем модуль
#
# $К_{расчетное} =T_{расчетное} = \frac {198.5-200}{\frac{\sigma}{\sqrt{n}}}=\frac {0.5}{\frac{4.45}{\sqrt{10}}}=\frac {0.5}{\frac{4.45}{3.16}}=\frac{0.5*3.16}{4.45}=\frac{1.58}{4.45}=0.35$

# %% [markdown]
# $$\sigma_{несмещен} = \sqrt{\frac{\sum\limits_{i=1}^{n} (x_i - \overline{x})^2}{n-1}}$$

# %% [markdown]
# $\sigma_{несмещен}=\sqrt{\frac{(202-198.5)^2+(203-198.5)^2+(199-198.5)^2+(197-198.5)^2+(195-198.5)^2+(201-198.5)^2+(200-198.5)^2+(204-198.5)^2+(194-198.5)^2+(190-198.5)^2}{100-1}}=\sqrt{\frac{(3.5)^2+(4.5)^2+(0.5)^2+(-1.5)^2+(-3.5)^2+(2.5)^2+(1.5)^2+(5.5)^2+(-4.5)^2+(-8.5)^2}{100-1}}=\sqrt{\frac{178.5}{9}}=\frac{\sqrt{178.5}}{3}=4.453$
#
# $T_{табличное} = 1.833$ согласно таблице Стьюдента
#
# $T_{расчетное} < T_{табличное}$ принимаем гипотезу $H_{0}$
#
# Ответ: верное значение среднего веса пачки = 200 гр.

# %%
202+203+199+197+195+201+200+204+194+190
# Out:
# 1985

# %%
3.5*3.5+4.5*4.5+0.5*0.5+1.5*1.5+3.5*3.5+2.5*2.5+1.5*1.5+5.5*5.5+4.5*4.5+8.5*8.5
# Out:
# 178.5

# %%
np.sqrt(178.5)
# Out:
# 13.360389215887388

# %%
a=[202, 203, 199, 197, 195, 201, 200, 204, 194, 190]
np.var(a, ddof=1)
# Out:
# 19.833333333333332

# %%
np.sqrt(19.83)
# Out:
# 4.453088815642463

# %%
np.sqrt(10)
# Out:
# 3.1622776601683795
